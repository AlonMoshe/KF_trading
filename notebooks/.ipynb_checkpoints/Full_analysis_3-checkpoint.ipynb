# %%
import sys, os

# Add KF_scripts to sys.path
KF_SCRIPTS_DIR = os.path.abspath(os.path.join(os.getcwd(), ".."))
if KF_SCRIPTS_DIR not in sys.path:
    sys.path.append(KF_SCRIPTS_DIR)

print("Added to sys.path:", KF_SCRIPTS_DIR)

# === 1. Imports ===
import pandas as pd
import numpy as np
import plotly.graph_objects as go
# Out:
# Added to sys.path: C:\Users\User\OneDrive\Projects\TradingSystem\KF_TradingSystem

# %% [markdown]
# **Process raw data**

# %%
from src.data.data_utils import process_raw_to_processed, load_processed_df

# df_proc = process_raw_to_processed("QQQ", "2025-12-04", "2025-12-05", 5, overwrite=True)

# df_loaded = load_processed_df("QQQ", "2025-12-03", "2025-12-03", 5)
# df_loaded.columns

# %% [markdown]
# **Back test**

# %%
from src.quant.backtesting import run_backtest_range

results = run_backtest_range(
    symbol="QQQ",
    start_date="2025-11-21",
    end_date="2025-12-05",
    interval=5,
    window_max=500,
    verbose=True,
    Q_high=0.90,
    slope_smooth=True,
    # slope_smooth=False, 
    slope_smooth_window=5,
    cooldown=23,
    slope_peak_half_window=2,
    slope_peak_hysteresis=0.0005,   # try small values like 0.0002–0.001
)

results
# Out:
# QQQ 2025-11-21: trades=50, PnL=-3.0400
# [WARN] QQQ 2025-11-22: no intraday data in file, skipping.
# [WARN] QQQ 2025-11-23: no intraday data in file, skipping.
# QQQ 2025-11-24: trades=50, PnL=0.3900
# QQQ 2025-11-25: trades=59, PnL=-0.3500
# QQQ 2025-11-26: trades=55, PnL=0.4500
# [WARN] QQQ 2025-11-27: no intraday data in file, skipping.
# QQQ 2025-11-28: trades=25, PnL=0.8700
# [WARN] QQQ 2025-11-29: no intraday data in file, skipping.
# [WARN] QQQ 2025-11-30: no intraday data in file, skipping.
# QQQ 2025-12-01: trades=45, PnL=-2.4700
# QQQ 2025-12-02: trades=48, PnL=-3.7400
# QQQ 2025-12-03: trades=49, PnL=0.2600
# QQQ 2025-12-04: trades=50, PnL=-1.5500
# QQQ 2025-12-05: trades=50, PnL=-0.2700
#          date symbol  num_trades  total_pnl   avg_pnl  long_pnl  short_pnl  \
# 0  2025-11-21    QQQ          50      -3.04 -0.060800     -2.94      -0.10
# 1  2025-11-24    QQQ          50       0.39  0.007800      1.51      -1.12
# 2  2025-11-25    QQQ          59      -0.35 -0.005932     -0.36       0.01
# 3  2025-11-26    QQQ          55       0.45  0.008182      1.03      -0.58
# 4  2025-11-28    QQQ          25       0.87  0.034800      0.88      -0.01
# 5  2025-12-01    QQQ          45      -2.47 -0.054889     -2.94       0.47
# 6  2025-12-02    QQQ          48      -3.74 -0.077917     -2.40      -1.34
# 7  2025-12-03    QQQ          49       0.26  0.005306      1.09      -0.83
# 8  2025-12-04    QQQ          50      -1.55 -0.031000     -0.54      -1.01
# 9  2025-12-05    QQQ          50      -0.27 -0.005400     -0.39       0.12
#
#    longest_trade  shortest_trade  avg_trade_duration
# 0             22               2           10.760000
# 1             67               2           11.920000
# 2             21               1           10.067797
# 3            372               1           16.672727
# 4            231               1           19.560000
# 5            361               1           27.288889
# 6            570               2           33.250000
# 7            405               1           26.734694
# 8            162               1           12.220000
# 9             45               2           11.720000

# %%
print("Overall Total PnL:", results["total_pnl"].sum())
print("Overall Number of Trades:", results["num_trades"].sum())
print("Average Daily PnL:", results["total_pnl"].mean())
