# %%
import sys, os

# Add KF_scripts to sys.path
KF_SCRIPTS_DIR = os.path.abspath(os.path.join(os.getcwd(), ".."))
if KF_SCRIPTS_DIR not in sys.path:
    sys.path.append(KF_SCRIPTS_DIR)

print("Added to sys.path:", KF_SCRIPTS_DIR)

# === 1. Imports ===
import pandas as pd
import numpy as np
import plotly.graph_objects as go
# Out:
# Added to sys.path: C:\Users\User\OneDrive\Projects\TradingSystem\KF_TradingSystem

# %% [markdown]
# **Process raw data**

# %%
from src.data.data_utils import process_raw_to_processed, load_processed_df

df_proc = process_raw_to_processed("QQQ", "2025-12-15", "2025-12-19", 5, overwrite=True)

# df_loaded = load_processed_df("QQQ", "2025-12-03", "2025-12-03", 5)
# df_loaded.columns

# %% [markdown]
# **Back test**

# %%
from src.quant.backtesting import run_backtest_range

results = run_backtest_range(
    symbol="QQQ",
    start_date="2025-11-21",
    end_date="2025-12-12",
    interval=5,
    window_max=100,
    verbose=True,
    Q_high=0.90,
    slope_smooth=True,
    # slope_smooth=False, 
    slope_smooth_window=5,
    cooldown=23,
    slope_peak_half_window=2,
    slope_peak_hysteresis=0.001,   # try small values like 0.0002–0.001
    slope_peak_min_swing=0.0,     # ← TRY VALUES 0.001–0.005
)

results
# Out:
# QQQ 2025-11-21: trades=14, PnL=1.1500
# [WARN] QQQ 2025-11-22: no intraday data in file, skipping.
# [WARN] QQQ 2025-11-23: no intraday data in file, skipping.
# QQQ 2025-11-24: trades=2, PnL=1.0400
# QQQ 2025-11-25: trades=5, PnL=-0.5300
# QQQ 2025-11-26: trades=2, PnL=-0.1000
# [WARN] QQQ 2025-11-27: no intraday data in file, skipping.
# QQQ 2025-11-28: trades=0, PnL=0.0000
# [WARN] QQQ 2025-11-29: no intraday data in file, skipping.
# [WARN] QQQ 2025-11-30: no intraday data in file, skipping.
# QQQ 2025-12-01: trades=3, PnL=-0.4600
# QQQ 2025-12-02: trades=1, PnL=-0.2000
# QQQ 2025-12-03: trades=2, PnL=0.0400
# QQQ 2025-12-04: trades=1, PnL=0.6500
# QQQ 2025-12-05: trades=0, PnL=0.0000
# QQQ 2025-12-06: no processed file, skipping.
# QQQ 2025-12-07: no processed file, skipping.
# QQQ 2025-12-08: trades=2, PnL=0.2300
# QQQ 2025-12-09: trades=1, PnL=-0.0500
# QQQ 2025-12-10: trades=3, PnL=0.6600
# QQQ 2025-12-11: trades=1, PnL=-0.2300
# QQQ 2025-12-12: trades=5, PnL=0.7000
#           date symbol  num_trades  total_pnl   avg_pnl  long_pnl  short_pnl  \
# 0   2025-11-21    QQQ          14       1.15  0.082143      2.90      -1.75
# 1   2025-11-24    QQQ           2       1.04  0.520000      1.52      -0.48
# 2   2025-11-25    QQQ           5      -0.53 -0.106000     -0.13      -0.40
# 3   2025-11-26    QQQ           2      -0.10 -0.050000     -0.16       0.06
# 4   2025-11-28    QQQ           0       0.00  0.000000      0.00       0.00
# 5   2025-12-01    QQQ           3      -0.46 -0.153333     -0.33      -0.13
# 6   2025-12-02    QQQ           1      -0.20 -0.200000      0.00      -0.20
# 7   2025-12-03    QQQ           2       0.04  0.020000      0.55      -0.51
# 8   2025-12-04    QQQ           1       0.65  0.650000      0.65       0.00
# 9   2025-12-05    QQQ           0       0.00  0.000000      0.00       0.00
# 10  2025-12-08    QQQ           2       0.23  0.115000      0.00       0.23
# 11  2025-12-09    QQQ           1      -0.05 -0.050000     -0.05       0.00
# 12  2025-12-10    QQQ           3       0.66  0.220000     -0.02       0.68
# 13  2025-12-11    QQQ           1      -0.23 -0.230000      0.00      -0.23
# 14  2025-12-12    QQQ           5       0.70  0.140000     -0.14       0.84
#
#     longest_trade  shortest_trade  avg_trade_duration
# 0              21               1           10.500000
# 1              25               5           15.000000
# 2              20               2           10.200000
# 3              12               7            9.500000
# 4               0               0            0.000000
# 5              16               2            9.333333
# 6               8               8            8.000000
# 7              13               6            9.500000
# 8              18              18           18.000000
# 9               0               0            0.000000
# 10             19               7           13.000000
# 11             11              11           11.000000
# 12             19               1           12.666667
# 13              7               7            7.000000
# 14             18               2           11.000000

# %%
print("Overall Total PnL:", results["total_pnl"].sum())
print("Overall Number of Trades:", results["num_trades"].sum())
print("Average Daily PnL:", results["total_pnl"].mean())
