# %%
import sys, os
import datetime as dt

# Add KF_scripts to sys.path
KF_SCRIPTS_DIR = os.path.abspath(os.path.join(os.getcwd(), ".."))
if KF_SCRIPTS_DIR not in sys.path:
    sys.path.append(KF_SCRIPTS_DIR)

print("Added to sys.path:", KF_SCRIPTS_DIR)

# === 1. Imports ===
import pandas as pd
import numpy as np
import plotly.graph_objects as go
# Out:
# Added to sys.path: C:\Users\User\OneDrive\Projects\TradingSystem\KF_TradingSystem

# %% [markdown]
# **Load processed data and execute entry and exit**

# %%
from src.quant.backtesting import one_day_backtest


# 1. Run simulation
df_day, df_trades, summary = one_day_backtest(
    "QQQ",
    2025, 11, 21,
    Q_high=0.9,
    window_max=500,
    cooldown=23,
    slope_smooth=True,
    # slope_smooth=False, 
    slope_smooth_window=5
)


# 3. Print summary
print(summary)
# df_trades
# Out:
# QQQ 2025-11-21: Trades=80, Total=-7.8700, Avg=-0.0984
# {'symbol': 'QQQ', 'date': datetime.date(2025, 11, 21), 'total_pnl': np.float64(-7.8700000000000045), 'num_trades': 80, 'avg_pnl': np.float64(-0.09837500000000006)}

# %%
# 7 — now plot

# Plotting
from src.visualization.plot_utils import plot_price_signals
plot_price_signals(
    df_day,
    # trades=None,
    trades=df_trades,
    price_cols=("Mid", "KF_level_adapt"),
    secondary_cols=("KF_slope_adapt",),
    secondary_scale=1000,
    show_peaks=True,
    show_signals=True,
    show_real_trades=True,
    show_trade_lines=True,
    title="QQQ – Entries & Exits"
)

# %%
# Quick sanity check
df_day[["entry_long", "exit_long", "entry_short", "exit_short"]].sum()

# %%
t1="2025-11-21 10:19:40-05:00"
t = "2025-11-21 10:19:55-05:00"


df_day.loc[t1:t, [
    "KF_slope_adapt",
    "region_max",
     "region_min",
    "slope_q_roll_daily",
    "slope_peak_max",
    "slope_peak_min",
    "slope_peak_min_raw",
    "slope_peak_max_raw",
    "entry_short"
]]
# Out:
#                            KF_slope_adapt  region_max  region_min  \
# Datetime
# 2025-11-21 10:19:40-05:00        0.031185        True       False
# 2025-11-21 10:19:45-05:00        0.030561        True       False
# 2025-11-21 10:19:50-05:00        0.028554        True       False
# 2025-11-21 10:19:55-05:00        0.026326        True       False
#
#                            slope_q_roll_daily  slope_peak_max  slope_peak_min  \
# Datetime
# 2025-11-21 10:19:40-05:00               0.956           False           False
# 2025-11-21 10:19:45-05:00               0.946           False           False
# 2025-11-21 10:19:50-05:00               0.926            True           False
# 2025-11-21 10:19:55-05:00               0.914           False           False
#
#                            slope_peak_min_raw  slope_peak_max_raw  entry_short
# Datetime
# 2025-11-21 10:19:40-05:00               False               False        False
# 2025-11-21 10:19:45-05:00               False               False        False
# 2025-11-21 10:19:50-05:00               False               False         True
# 2025-11-21 10:19:55-05:00               False               False        False

# %%
df_trades.columns

# %%
# df_trades_sorted=df_trades.sort_index()
df_trades = df_trades.sort_values("entry_time").reset_index(drop=True)
df_trades.head

# %%
t = "2025-11-21 15:12:50-05:00"
# df_day.loc[t, ["entry_short", "exit_short", "trade_id_short"]]
df_trades[df_trades['entry_time'] == '09:37:20-05:00']
df_trades[df_trades['entry_time'] == t]

# %%
df_trades.info()

# %%
df_day.columns

# %%
df_day.loc["2025-11-21 15:12:00":"2025-11-21 15:13:00", ["entry_short"]].sum()

# %%
df_day[df_day["entry_short"] == True]

# %%
from src.visualization.double_axis_plot import plot_dual_axis


plot_dual_axis(
    df_day,
    ['KF_slope_adapt'],['KF_curv_adapt'] )
